# %% [markdown]
# <a href="https://colab.research.google.com/github/hursoo/big_k-modern_1/blob/main/gb_111_topic_in_text(big1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.개요 및 기본 설정
# - 토픽과 실제 논설의 매칭
# - 분석과 사료 간 대조
# - 토픽모델링의 경험적 분석 도구 용도 관련

# %%
# =================================================================
# 셀 1: 필수 라이브러리 및 한글 폰트 설치
# =================================================================
# ⚠️ 이 셀을 실행한 후에는 반드시 "런타임 다시 시작"을 해야 합니다.

# 1. 라이브러리 설치 (최신 호환 버전)
# !pip install -q tomotopy kneed

# 2. 나눔 폰트 설치
# !sudo apt-get -qq install fonts-nanum*

# 3. 폰트 캐시 재생성
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

print("✅ 라이브러리 및 한글 폰트 설치가 완료되었습니다.")
print("🔴 중요: 지금 바로 메뉴에서 [런타임] > [세션 다시 시작]을 실행하세요!")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 695.9 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 25.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 126371 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-3_all.deb ...
# Unpacking fonts-nanum-coding (2.5-3) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-7_all.deb ...
# Unpacking fonts-nanum-eco (1.000-7) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20200506-1_all.deb ...
# Unpacking fonts-nanum-extra (20200506-1) ...
# Setting up fonts-nanum-extra (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Setting up fonts-nanum-coding (2.5-3) ...
# Setting up fonts-nanum-eco (1.000-7) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 39 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
# ✅ 라이브러리 및 한글 폰트 설치가 완료되었습니다.
# 🔴 중요: 지금 바로 메뉴에서 [런타임] > [세션 다시 시작]을 실행하세요!

# %%
# =================================================================
# 셀 2: 기본 설정 및 라이브러리 임포트
# =================================================================
# "세션 다시 시작" 후에 이 셀부터 실행합니다.

# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
print("\n✅ 구글 드라이브 마운트 완료!")

# 경로 지정
file_path = '/content/drive/MyDrive/big_km_history01/'

# 라이브러리 임포트
import sys
import os, re
import pandas as pd
import numpy as np
print(np.__version__)
import random
import warnings

from tomotopy import DMRModel
from tomotopy import TermWeight
from tomotopy import utils
import tomotopy as tp

# ⚠️ 한글 폰트 설정 코드를 여기에 배치합니다.
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic') # 나눔바른고딕으로 설정
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

print("✅ 기본 설정 및 라이브러리 임포트 완료!")

# 그래프 한글 표시 테스트
plt.figure(figsize=(5, 3))
plt.title('성공한 한글 제목!')
plt.xlabel('X축 라벨')
plt.ylabel('Y축 라벨')
plt.plot([1, 5, 2, 8], label='데이터')
plt.legend()
plt.show()
# Out:
# Mounted at /content/drive
#
# ✅ 구글 드라이브 마운트 완료!
# 1.26.4
# ✅ 기본 설정 및 라이브러리 임포트 완료!

# %% [markdown]
# # 2.데이터 불러오기

# %% [markdown]
# ## 2.1.통합 데이터

# %%
# 통합 데이터 불러오기
df = pd.read_excel(file_path + 'result/gb_data_2(doc,1g2g,wn_cls).xlsx') ###
df[:3]
# 1기, 2기: doc_id는 3046부터 끝까지
df['period'] = np.where(
    df['doc_id'] < 3046,  # 조건
    'p1',                          # 조건이 참일 때
    'p2'                           # 조건이 거짓일 때
)
df
# Out:
#       doc_id                                            doc_raw  \
# 0          1  創刊辭 强者도 부르짖고 弱者도 부르짖으며 優者도 부르짖고 劣者도 부르짖도다 東西南北...
# 1          2  哲人은 말하되 多數 人民의 聲은 곳 神의 聲이라 하엿나니 神은 스스로 要求가 없는지...
# 2          3  世界를 알라 사람은 天使도 안이며 野獸도 안이오 오즉 사람일 뿐이로다 이만치 進化된...
# 3          4  사람과 世界는 決코 논하볼 것이 안이엇다 사람으로 된 世界 世界로 된 사람 둘이 안...
# 4          5  過去는 論할 것이 업도다만은 今日과 가티 交通이 이마마하고 知識이 이마마하고 一切의...
# ...      ...                                                ...
# 6797    6798  미국에서는 每人에게 奴僕이 식 돌아감니다 단 機械奴僕만 이건 무슨 말이냐 하면 기계...
# 6798    6799  매년 저축은ㅡ필요의 비용을 다 쓴 뒤의 것 말이지요ㅡ매년에 억 딸라 金 루불로는 억...
# 6799    6800  그러고 또 캐나다는 아조 겸손스럽게 좀 유순하게 미국의 北邊繼續이라고ㅡ국제연맹의 축...
# 6800    6801  25년 전에는 영국이 美보다 배나 더 되게 輸入하엿섯음니다 캐나다 사람들은 지금 그...
# 6801    6802  어떠케 되엿던지 만약 미국과 영국간에 전쟁이 生起인다면 영국의 또미니온인 캐나다는 ...
#
#                                        doc_split_12gram  r_no  \
# 0     창간 辭 강자 약자 優者 劣者 동서 남북 사해 팔방 소리 소리 판단 좌우 間 다수 ...     1
# 1     哲人 다수 인민 요구 인민 소리 요구 발표 갈앙 인민 소리 갈앙 다수 인민 갈앙 요...     1
# 2     세계 사람 야수 사람 진화 진화 지식 진화 도덕 동물 세계 천당 지옥 세계 진화 국...     2
# 3     사람 세계 사람 세계 세계 사람 세계 대표 시대 가치 사람 대표 문화 상징 符號 사...     2
# 4     過去 금일 교통 지식 일체 문물 오늘 세계 理解 공자 천하 천하 理解 오늘 날 사람...     2
# ...                                                 ...   ...
# 6797  미국 노복 機械 노복 機械 力 운전 계산 人力 계산 미국 국민 사람 機械 輸入 숫자...   334
# 6798  저축 필요 비용 미국 교과 書 실상 미국 富豪 캐나다 영국 미국 부분 미국 캐나다 ...   334
# 6799  캐나다 미국 국제_연맹 국제_연맹 원인 경제 機械 캐나다 산업 북미 자본 점령 부분...   334
# 6800  영국 미국 輸入 캐나다 사람 영국 一部 미국 호주 캐나다 진화 호주 일본 침입 보호...   334
# 6801  미국 영국 전쟁 生起 영국 캐나다 미국 양식 힘 영국 비밀 정객 미국 영국 캐나다 ...   334
#
#                                                   title w_new  ho_no grid_1  \
# 0                                                   創刊辭  uk01      1    01q
# 1                                                   創刊辭  uk01      1    01q
# 2                                                世界를 알라  uk01      1    01q
# 3                                                世界를 알라  uk01      1    01q
# 4                                                世界를 알라  uk01      1    01q
# ...                                                 ...   ...    ...    ...
# 6797  유로빠와 아메리카(一) 금년 봄에 모쓰크바 엑쓰페리멘탈 劇場에서 한 「트로츠끼」의 講演.   김철산     72    24q
# 6798  유로빠와 아메리카(一) 금년 봄에 모쓰크바 엑쓰페리멘탈 劇場에서 한 「트로츠끼」의 講演.   김철산     72    24q
# 6799  유로빠와 아메리카(一) 금년 봄에 모쓰크바 엑쓰페리멘탈 劇場에서 한 「트로츠끼」의 講演.   김철산     72    24q
# 6800  유로빠와 아메리카(一) 금년 봄에 모쓰크바 엑쓰페리멘탈 劇場에서 한 「트로츠끼」의 講演.   김철산     72    24q
# 6801  유로빠와 아메리카(一) 금년 봄에 모쓰크바 엑쓰페리멘탈 劇場에서 한 「트로츠끼」의 講演.   김철산     72    24q
#
#       wn_cls period
# 0          0     p1
# 1          0     p1
# 2          0     p1
# 3          0     p1
# 4          0     p1
# ...      ...    ...
# 6797       2     p2
# 6798       2     p2
# 6799       2     p2
# 6800       2     p2
# 6801       2     p2
#
# [6802 rows x 10 columns]

# %%
df['r_no']
# Out:
# 0         1
# 1         1
# 2         2
# 3         2
# 4         2
#        ...
# 6797    334
# 6798    334
# 6799    334
# 6800    334
# 6801    334
# Name: r_no, Length: 6802, dtype: int64

# %%
# 저장

# df.to_excel(file_path + 'result/gb_data_2(doc,1g2g,wn_cls)_period.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6802 entries, 0 to 6801
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   doc_id            6802 non-null   int64
#  1   doc_raw           6802 non-null   object
#  2   doc_split_12gram  6802 non-null   object
#  3   r_no              6802 non-null   int64
#  4   title             6802 non-null   object
#  5   w_new             6802 non-null   object
#  6   ho_no             6802 non-null   int64
#  7   grid_1            6802 non-null   object
#  8   wn_cls            6802 non-null   int64
#  9   period            6802 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 531.5+ KB

# %% [markdown]
# ## 2.2.문서별 토픽비중

# %%
# 문서별 토픽비중 불러오기

doc_dist = pd.read_csv(file_path + 'result/doc-distrib.txt', sep='\t')
doc_dist.drop(columns=['Unnamed: 0'], inplace=True)
doc_dist['doc_id'] = doc_dist.index + 1
doc_dist.set_index('doc_id', inplace=True)
doc_dist
# Out:
#               T0        T1        T2        T3        T4        T5        T6  \
# doc_id
# 1       0.100175  0.000584  0.005788  0.000916  0.699498  0.007016  0.181811
# 2       0.242115  0.000204  0.016817  0.000319  0.022108  0.313191  0.403775
# 3       0.013623  0.000518  0.005135  0.000812  0.357190  0.570561  0.048423
# 4       0.170529  0.000538  0.005336  0.000844  0.058408  0.671052  0.089409
# 5       0.701495  0.000366  0.003632  0.000575  0.066367  0.217282  0.007639
# ...          ...       ...       ...       ...       ...       ...       ...
# 6798    0.003296  0.014734  0.604653  0.085668  0.000684  0.001389  0.163286
# 6799    0.004578  0.020463  0.062022  0.007873  0.000949  0.001929  0.449007
# 6800    0.003746  0.016743  0.232563  0.051896  0.000777  0.001578  0.003735
# 6801    0.004120  0.018417  0.005820  0.007086  0.000854  0.101735  0.004108
# 6802    0.002424  0.010834  0.032835  0.357108  0.000503  0.089256  0.002417
#
#               T7
# doc_id
# 1       0.004213
# 2       0.001470
# 3       0.003738
# 4       0.003884
# 5       0.002644
# ...          ...
# 6798    0.126290
# 6799    0.453179
# 6800    0.688963
# 6801    0.857859
# 6802    0.504624
#
# [6802 rows x 8 columns]

# %% [markdown]
# # 3.문서 속 토픽
# - 문서군 단위가 효과적
# - 문서군: 문서를 5개씩 묶음.  cf) 문서: 5개 문장을 단위로 함

# %%
df.head()
# Out:
#    doc_id                                            doc_raw  \
# 0       1  創刊辭 强者도 부르짖고 弱者도 부르짖으며 優者도 부르짖고 劣者도 부르짖도다 東西南北...
# 1       2  哲人은 말하되 多數 人民의 聲은 곳 神의 聲이라 하엿나니 神은 스스로 要求가 없는지...
# 2       3  世界를 알라 사람은 天使도 안이며 野獸도 안이오 오즉 사람일 뿐이로다 이만치 進化된...
# 3       4  사람과 世界는 決코 논하볼 것이 안이엇다 사람으로 된 世界 世界로 된 사람 둘이 안...
# 4       5  過去는 論할 것이 업도다만은 今日과 가티 交通이 이마마하고 知識이 이마마하고 一切의...
#
#                                     doc_split_12gram  r_no   title w_new  \
# 0  창간 辭 강자 약자 優者 劣者 동서 남북 사해 팔방 소리 소리 판단 좌우 間 다수 ...     1     創刊辭  uk01
# 1  哲人 다수 인민 요구 인민 소리 요구 발표 갈앙 인민 소리 갈앙 다수 인민 갈앙 요...     1     創刊辭  uk01
# 2  세계 사람 야수 사람 진화 진화 지식 진화 도덕 동물 세계 천당 지옥 세계 진화 국...     2  世界를 알라  uk01
# 3  사람 세계 사람 세계 세계 사람 세계 대표 시대 가치 사람 대표 문화 상징 符號 사...     2  世界를 알라  uk01
# 4  過去 금일 교통 지식 일체 문물 오늘 세계 理解 공자 천하 천하 理解 오늘 날 사람...     2  世界를 알라  uk01
#
#    ho_no grid_1  wn_cls period
# 0      1    01q       0     p1
# 1      1    01q       0     p1
# 2      1    01q       0     p1
# 3      1    01q       0     p1
# 4      1    01q       0     p1

# %%
doc_dist.head()
# Out:
#               T0        T1        T2        T3        T4        T5        T6  \
# doc_id
# 1       0.100175  0.000584  0.005788  0.000916  0.699498  0.007016  0.181811
# 2       0.242115  0.000204  0.016817  0.000319  0.022108  0.313191  0.403775
# 3       0.013623  0.000518  0.005135  0.000812  0.357190  0.570561  0.048423
# 4       0.170529  0.000538  0.005336  0.000844  0.058408  0.671052  0.089409
# 5       0.701495  0.000366  0.003632  0.000575  0.066367  0.217282  0.007639
#
#               T7
# doc_id
# 1       0.004213
# 2       0.001470
# 3       0.003738
# 4       0.003884
# 5       0.002644

# %% [markdown]
# ## 3.1.문서군 생성
# - 목적: 문서를 5개씩 묶어서 문서군을 생성
# - 이유: 토픽을 실제 본문에서 확인하기 용이하게 함.
# - 방식: 논설 단위. 잔여 문서 수가 3개, 4개면 독립 문서군으로, 2개 이하면 그 앞 문서군에 통합

# %%
import pandas as pd
import numpy as np

def create_doc_groups(df, doc_dist):
    """
    논설(r_no)별로 문서를 5개씩 묶어 '문서군'을 생성하는 함수입니다.
    """

    # doc_dist의 doc_id 인덱스 해제
    doc_dist = doc_dist.reset_index('doc_id')

    processed_groups = []

    for r_no, article_df in df.groupby('r_no'):
        docs_in_article = article_df.to_dict('records')
        num_docs = len(docs_in_article)
        temp_groups = []

        for i in range(0, num_docs, 5):
            temp_groups.append(docs_in_article[i:i+5])

        if len(temp_groups) > 1:
            last_group = temp_groups[-1]
            num_remainder = len(last_group)

            if num_remainder <= 2:
                merged_group = temp_groups[-2] + last_group
                temp_groups = temp_groups[:-2] + [merged_group]

        for group in temp_groups:
            doc_ids = [doc['doc_id'] for doc in group]
            topic_avg = doc_dist[doc_dist['doc_id'].isin(doc_ids)].iloc[:, 1:].mean()

            group_info = {
                'r_no': group[0]['r_no'],
                'title': group[0]['title'],
                'w_new': group[0]['w_new'],
                'wn_cls': group[0]['wn_cls'],
                'ho_no': group[0]['ho_no'],
                'period': group[0]['period'],
                'included_doc_ids': doc_ids,
                'doc_count': len(doc_ids),
                'doc_raw_combined': ' '.join([str(doc['doc_raw']) for doc in group]),
                # doc_split_12gram 내용을 통합하여 새 열에 추가
                'doc_split_combined': ' '.join([str(doc['doc_split_12gram']) for doc in group])
            }

            for topic, value in topic_avg.items():
                group_info[topic] = value

            processed_groups.append(group_info)

    final_df = pd.DataFrame(processed_groups)
    final_df.insert(0, '문서군_번호', range(1, len(final_df) + 1))

    return final_df

# 함수 실행
doc_groups_df = create_doc_groups(df, doc_dist)

# 결과 확인
print("생성된 문서군 데이터프레임 (상위 5개)")
print(doc_groups_df.head())

# 수정된 파일명으로 CSV 저장
output_filename = "result/gb_data_2_doc-groups.csv"
doc_groups_df.to_csv(file_path + output_filename, index=False, encoding='utf-8-sig')

print(f"\n'{output_filename}' 파일이 성공적으로 저장되었습니다.")
# Out:
# 생성된 문서군 데이터프레임 (상위 5개)
#    문서군_번호  r_no   title w_new  wn_cls  ho_no period      included_doc_ids  \
# 0       1     1     創刊辭  uk01       0      1     p1                [1, 2]
# 1       2     2  世界를 알라  uk01       0      1     p1       [3, 4, 5, 6, 7]
# 2       3     2  世界를 알라  uk01       0      1     p1    [8, 9, 10, 11, 12]
# 3       4     2  世界를 알라  uk01       0      1     p1  [13, 14, 15, 16, 17]
# 4       5     2  世界를 알라  uk01       0      1     p1  [18, 19, 20, 21, 22]
#
#    doc_count                                   doc_raw_combined  \
# 0          2  創刊辭 强者도 부르짖고 弱者도 부르짖으며 優者도 부르짖고 劣者도 부르짖도다 東西南北...
# 1          5  世界를 알라 사람은 天使도 안이며 野獸도 안이오 오즉 사람일 뿐이로다 이만치 進化된...
# 2          5  다만 오늘이라 하는 今日의 우리엇다 今日을 吟味하고 今日을 등에 진 우리엇다 今日의...
# 3          5  이를 抽象的으로 말하면 正義人道의 發現이오 平等 自由의 目標라 하겟고 具體的으로 말...
# 4          5  이른바 世界大勢의 順應이라 하며 世界思潮의 迎合이라 함은 今日 以後에 徹底로 나타날...
#
#                                   doc_split_combined        T0        T1  \
# 0  창간 辭 강자 약자 優者 劣者 동서 남북 사해 팔방 소리 소리 판단 좌우 間 다수 ...  0.171145  0.000394
# 1  세계 사람 야수 사람 진화 진화 지식 진화 도덕 동물 세계 천당 지옥 세계 진화 국...  0.285526  0.000485
# 2  오늘 금일 금일 음미 금일 금일 사회 금일 세계 세계 범위 활동 세계 地圖 축소 걸...  0.552174  0.000581
# 3  추상 正義 人道 발현 평등 자유 목표 구체 강약 공존 主義 강자 약자 권리 調和 富...  0.039179  0.000244
# 4  세계 대세 순응 세계 사조 영합 금일 철저 安全 행복 安全 세계 처음 실현 세계 필...  0.246568  0.000418
#
#          T2        T3        T4        T5        T6        T7
# 0  0.011303  0.000618  0.360803  0.160104  0.292793  0.002842
# 1  0.004810  0.000761  0.142690  0.409134  0.041098  0.115495
# 2  0.062645  0.000912  0.214162  0.098196  0.039923  0.031408
# 3  0.016561  0.000383  0.628343  0.132073  0.007888  0.175329
# 4  0.008097  0.007852  0.480688  0.236578  0.008713  0.011086
#
# 'result/gb_data_2_doc-groups.csv' 파일이 성공적으로 저장되었습니다.

# %% [markdown]
# ## 3.2.문서군, 논설명으로 접근

# %%
import pandas as pd

def extract_and_highlight_documents_by_id(docs_filepath, topics_filepath, doc_group_no=None, r_no=None, n=None):
    """
    지정된 문서군_번호나 r_no에 해당하는 문서를 추출하고, 토픽 단어를 강조하여 출력하는 함수입니다.

    Args:
        docs_filepath (str): 문서 그룹 데이터 파일 경로 ('gb_data_2_doc-groups.csv')
        topics_filepath (str): 토픽 단어 데이터 파일 경로 ('dmr_topics(토픽명 부착).csv')
        doc_group_no (int, optional): 필터링할 문서군_번호. 기본값은 None.
        r_no (int, optional): 필터링할 r_no. 기본값은 None.
        n (int, optional): 출력할 최대 문서군 개수. 기본값은 None (전체 출력).

    Returns:
        str: 형식에 맞게 가공된 결과 문자열. 해당하는 문서가 없으면 안내 메시지를 반환합니다.
    """
    # --- 1. 데이터 파일 읽기 ---
    try:
        topics_df = pd.read_csv(topics_filepath)
        docs_df = pd.read_csv(docs_filepath)
    except FileNotFoundError as e:
        return f"오류: 파일을 찾을 수 없습니다. {e}"

    # --- 2. 전체 토픽 단어 목록 생성 ---
    all_topic_words = set()
    topic_word_dict = {} # 각 토픽별 단어를 저장할 딕셔너리

    topic_cols = [f'T{i}' for i in range(len(topics_df))]  ###

    for _, row in topics_df.iterrows():
        topic_name = f"T{row['Topic_Index']}"  ###
        words = {word.strip() for word in row['Top_Words'].split(',')}
        all_topic_words.update(words)
        topic_word_dict[topic_name] = words

    # --- 3. 매개변수에 따른 문서 데이터 필터링 ---
    filtered_df = docs_df.copy()

    # doc_group_no 또는 r_no로 필터링
    if doc_group_no is not None:
        filtered_df = filtered_df[filtered_df['문서군_번호'] == doc_group_no]

    if r_no is not None:
        filtered_df = filtered_df[filtered_df['r_no'] == r_no]

    # --- 4. 결과 문자열 생성 ---
    if filtered_df.empty:
        return f"결과 없음: 해당 조건(문서군_번호: {doc_group_no}, r_no: {r_no})의 문서가 없습니다."

    # 출력 개수(n) 제한 적용
    if n is not None and isinstance(n, int) and n > 0:
        display_df = filtered_df.head(n)
    else:
        display_df = filtered_df

    output_string = ""
    for _, row in display_df.iterrows():
        # 해당 문서의 주 토픽(dominant topic)을 찾음
        dominant_topic = row[topic_cols].idxmax()
        target_topic_words = topic_word_dict.get(dominant_topic, set())

        # 'doc_split_combined' 내용에서 토픽 단어 강조
        doc_words = row['doc_split_combined'].split(' ')
        highlighted_words = []
        for word in doc_words:
            if word in target_topic_words:
                highlighted_words.append(f"**{word}**")
            elif word in all_topic_words:
                highlighted_words.append(f"*{word}*")
            else:
                highlighted_words.append(word)
        highlighted_doc = ' '.join(highlighted_words)

        # 각 문서군의 정보를 문자열에 추가
        output_string += f"문서군_번호: {row['문서군_번호']}\n"
        output_string += f"r_no: {row['r_no']}\n"
        output_string += f"title: {row['title']}\n"
        output_string += f"w_new: {row['w_new']}\n"
        output_string += f"wn_cls: {row['wn_cls']}\n"
        output_string += f"ho_no: {row['ho_no']}\n"
        output_string += f"period: {row['period']}\n"
        output_string += f"included_doc_ids: {row['included_doc_ids']}\n"
        output_string += f"doc_count: {row['doc_count']}\n"
        output_string += f"doc_raw_combined: {row['doc_raw_combined']}\n"
        output_string += f"doc_split_combined: {highlighted_doc}\n"
        output_string += "-----\n"

    return output_string

# --- 함수 실행 예시 ---
if __name__ == "__main__":
    # 파일 경로는 실제 파일 위치에 맞게 수정해야 합니다.
    DOCS_FILE = file_path + 'result/gb_data_2_doc-groups.csv'
    TOPICS_FILE = file_path + 'result/dmr_topics(토픽명 부착).csv'

    # --- 예시 1: 문서군_번호가 153인 문서 출력 ---
    print("--- 예시 1: 문서군_번호가 190인 결과 ---")
    result_1 = extract_and_highlight_documents_by_id(
        docs_filepath=DOCS_FILE,
        topics_filepath=TOPICS_FILE,
        doc_group_no=190, ###
        r_no=53 ###
    )
    print(result_1)
# Out:
# --- 예시 1: 문서군_번호가 190인 결과 ---
# 문서군_번호: 190
# r_no: 53
# title: 社會問題에 先하야 自我問題에 反하라. 그리하야 社會에 對한 公僕이 되라
# w_new: 박달성
# wn_cls: 1
# ho_no: 12
# period: p1
# included_doc_ids: [928, 929, 930, 931, 932]
# doc_count: 5
# doc_raw_combined: 아 現代人아 自己를 確實히 알앗거든 人生의 如何를 深切히 覺悟하얏거든 萬人平等을 事實로 느꼇거든 覺悟한 그대로 느낀 그대로 各自 스스로가 몸소 實行하라 이써 나에 呌苦하는 問題의 세 번재이다 4 過去의 非와 今後의 是 人生의 目的이 快樂이라 하면 人生으로서는 老者 壯者 少者 男子 女子 兒童까지 누구나 다 快樂을 要求할 것이다 然한데 웨 어떤 者는 快樂의 座에서 歡喜의 웃음을 웃으며 웨 어떤者는 悲哀의 窟에서 苦痛의 눈물을 흘리고 잇는가 나는 써하되 悲哀者 스스로의 罪라 한다 人生의 目的이 功利이라 하면 또한 다 功利의 人이 되어야 되겟다 그런데 어떤 놈은 功利의 榮冠을 쓰고 어떤 놈은 退敗의 悲曲을 부르니 이것은 또한 누의 罪이겟는가 決코 功利者의 罪는 아니라 한다 人生의 目的이 自己充實이면 이도 또한 人生 全體가 다 充實하여야겟거늘 어떤 者는 充實하고 어떤 者는 不充實하니 이 또한 不充實者 스스로의 罪가 아니냐 가튼 사람으로 가튼 欲望으로 왜 快樂치 못하며 功利치 못하며 充實치 못하얏느냐 彼等의 快樂 彼等의 功利 彼等에 充實은 彼等 스스로가 努力하야 어든 것이며 또한 이 不快樂者 不功利者 不充實者로서 보내 준 것이며 도아 준 것이다 다시 말하면 彼가 快樂키 爲하야 高臺를 築하며 奴僕을 募하거늘 此로서는 勞役者가 되어 주며 奴僕으로 自進한 것이 아니냐 大將은 功利를 爲하야 만흔 犧牲을 要求하거늘 兵卒은 그 功利를 助力키 爲하야 水火自進한 것이 아니냐 彼는 知者이오 覺者이오 實力者이거늘 此는 웨 迷者며 愚者며 無力者인가 吾人은 權力家를 만히 罵倒하며 富貴者를 만히 彈劾하며 無勢力者를 만히 同情하며 貧賤者를 만히 後援하도다 吾人은 此로써 羞恥임을 不知하도다 社會에 對한 羞恥보다도 各自 自己에 對한 羞恥임을 不知하도다 니체는 일럿스되 弱者에 對한 同情처럼 罪惡이 업다 하얏나니 自己로 自己를 抛棄한 者에게 무슨 擧足의 値가 잇겟는가 그러나 此는 吾人의 經驗이 적엇든 過去의 事요 吾人의 覺醒이 不分明한 過去의 事이다 現代의 吾人은 決코 그러할 理 萬無하다 自己를 切實히 깨다른 자 어찌 如此한 不人格的 사람답지 못한 行爲가 잇슬 것이냐 今後의 人類社會는 決코 貧富貴賤 上下階級이 업슬 것을 나는 確實히 自保한다 그는 人類各自가 다 各其 自己의 權利義務를 覺하얏슴으로써 이다
# doc_split_combined: 현대_人 **自己** 확실 *인생* 深切 각오 만인 **평등** 각오 실행 *문제* *過去* 금후 *인생* 목적 쾌락 *인생* 남자 여자 아동 쾌락 요구 쾌락 환희 웃음 비애 고통 눈물 **者** 비애 *인생* 목적 功利 功利 功利 功利 **者** *인생* 목적 **自己** 충실 *인생* 전체 충실 충실 **사람** 욕망 쾌락 功利 충실 쾌락 功利 충실 노력 쾌락 노복 노역 **者** 노복 自進 功利 희생 요구 功利 知者 **者** 실력 권력 家 **者** 부귀 同情 **者** 빈천 후원 수치 不知 **사회** 수치 **自己** 수치 不知 니체 약자 同情 죄악 **自己** **自己** 포기 경험 *過去* 각성 *過去* 현대 **自己** 절실 **사람** 행위 금후 인류_사회 빈부 귀천 상하 **계급** 확실 **인류** 각자 **自己** 의무 권리
# -----

# %% [markdown]
# ## 3.3.필자분류, 토픽명으로 접근

# %% [markdown]
# ### 검토대상 문서군 추출

# %%
import pandas as pd

def get_topic_distribution(
    filepath,
    topic_no=None,
    w_new=None,
    doc_id=None,
    wn_cls=None,
    n=5
):
    """
    CSV 파일을 불러와 조건에 맞게 필터링하고, 특정 토픽 분포를 기준으로
    내림차순 정렬하여 상위 n개의 결과를 DataFrame으로 반환하는 함수입니다.

    Args:
        filepath (str): 불러올 CSV 파일의 경로.
        topic_no (str, optional): 정렬의 기준이 될 토픽 번호 (예: 'T3').
                                  None이면 정렬하지 않음. 기본값은 None.
        w_new (str, optional): 필터링할 필자명. 기본값은 None.
        doc_id (int, optional): 필터링할 논설 고유번호(r_no). 기본값은 None.
        wn_cls (int, optional): 필터링할 필자 분류. 기본값은 None.
        n (int, optional): 추출할 상위 결과의 개수. 기본값은 5.

    Returns:
        pandas.DataFrame: 조건에 맞게 필터링되고 정렬된 결과 데이터프레임.
    """
    try:
        df = pd.read_csv(filepath)
    except FileNotFoundError:
        print(f"오류: '{filepath}' 파일을 찾을 수 없습니다.")
        return None

    filtered_df = df.copy()

    # 매개변수 값에 따라 데이터 필터링
    if w_new is not None:
        filtered_df = filtered_df[filtered_df['w_new'] == w_new]

    if doc_id is not None:
        filtered_df = filtered_df[filtered_df['r_no'] == doc_id]

    if wn_cls is not None:
        filtered_df = filtered_df[filtered_df['wn_cls'] == wn_cls]

    # 지정된 토픽 번호로 내림차순 정렬
    topic_cols = [col for col in df.columns if col.startswith('T')]
    if topic_no is not None and topic_no in topic_cols:
        filtered_df = filtered_df.sort_values(by=topic_no, ascending=False)

    # 상위 n개 결과 추출 및 최종 컬럼 선택 (***수정된 부분***)
    result_cols = ['문서군_번호', 'r_no', 'title', 'w_new', 'wn_cls'] + topic_cols
    result_df = filtered_df.head(n)[result_cols]

    return result_df

# --- 함수 실행 예시 ---
if __name__ == "__main__":
    FILE_PATH = file_path + 'result/gb_data_2_doc-groups.csv'

    print("--- 예시: 필자 분류(wn_cls)가 1인 문서 중, T4 토픽 점수가 가장 높은 상위 5개 ---")  ###
    example_df = get_topic_distribution(
        filepath=FILE_PATH,
        wn_cls=1, ###
        topic_no='T4', ###
        n=5
    )
    print(example_df)
# Out:
# --- 예시: 필자 분류(wn_cls)가 1인 문서 중, T4 토픽 점수가 가장 높은 상위 5개 ---
#      문서군_번호  r_no                                              title w_new  \
# 189     190    53            社會問題에 先하야 自我問題에 反하라. 그리하야 社會에 對한 公僕이 되라   박달성
# 51       52    13                        從來의 孝道를 批判하야써 今後의 父子關係를 聲言함   김기전
# 260     261    71  生活의 條件을 本位로 한 朝鮮의 改造事業, 이 글을 特히 民族의 盛衰를 雙肩에 負한...   이돈화
# 307     308    79                           現代倫理思想의 槪觀, 東洋式 倫理思想의 變遷   이돈화
# 50       51    13                        從來의 孝道를 批判하야써 今後의 父子關係를 聲言함   김기전
#
#      wn_cls        T0        T1        T2        T3        T4        T5  \
# 189       1  0.019468  0.006111  0.002229  0.002148  0.834694  0.030436
# 51        1  0.078313  0.000468  0.005727  0.000320  0.819455  0.011296
# 260       1  0.048754  0.023279  0.011675  0.008115  0.816075  0.057423
# 307       1  0.113072  0.000452  0.000950  0.032634  0.795598  0.040301
# 50        1  0.123677  0.000510  0.002058  0.000349  0.786838  0.002251
#
#            T6        T7
# 189  0.103780  0.001133
# 51   0.083374  0.001047
# 260  0.024647  0.010032
# 307  0.016672  0.000322
# 50   0.078059  0.006257

# %%
example_df
# Out:
#      문서군_번호  r_no                                              title w_new  \
# 189     190    53            社會問題에 先하야 自我問題에 反하라. 그리하야 社會에 對한 公僕이 되라   박달성
# 51       52    13                        從來의 孝道를 批判하야써 今後의 父子關係를 聲言함   김기전
# 260     261    71  生活의 條件을 本位로 한 朝鮮의 改造事業, 이 글을 特히 民族의 盛衰를 雙肩에 負한...   이돈화
# 307     308    79                           現代倫理思想의 槪觀, 東洋式 倫理思想의 變遷   이돈화
# 50       51    13                        從來의 孝道를 批判하야써 今後의 父子關係를 聲言함   김기전
#
#      wn_cls        T0        T1        T2        T3        T4        T5  \
# 189       1  0.019468  0.006111  0.002229  0.002148  0.834694  0.030436
# 51        1  0.078313  0.000468  0.005727  0.000320  0.819455  0.011296
# 260       1  0.048754  0.023279  0.011675  0.008115  0.816075  0.057423
# 307       1  0.113072  0.000452  0.000950  0.032634  0.795598  0.040301
# 50        1  0.123677  0.000510  0.002058  0.000349  0.786838  0.002251
#
#            T6        T7
# 189  0.103780  0.001133
# 51   0.083374  0.001047
# 260  0.024647  0.010032
# 307  0.016672  0.000322
# 50   0.078059  0.006257

# %% [markdown]
# ### 세부조건 부여
# - 상위n개

# %%
import pandas as pd

def extract_and_highlight_documents(docs_filepath, topics_filepath, target_w_cls, target_topic, n=None):
    """
    지정된 필자 분류와 토픽에 해당하는 문서를 추출하고, 토픽 단어를 강조하여 출력하는 함수입니다.

    Args:
        docs_filepath (str): 문서 그룹 데이터 파일 경로 ('gb_data_2_doc-groups.csv')
        topics_filepath (str): 토픽 단어 데이터 파일 경로 ('dmr_topics(토픽명 부착).csv')
        target_w_cls (int): 필터링할 필자 분류 번호 (wn_cls)
        target_topic (str): 필터링할 토픽 이름 (예: 'T3')
        n (int, optional): 출력할 최대 문서군 개수. 기본값은 None (전체 출력).

    Returns:
        str: 형식에 맞게 가공된 결과 문자열. 해당하는 문서가 없으면 안내 메시지를 반환합니다.
    """
    # --- 1. 데이터 파일 읽기 ---
    try:
        topics_df = pd.read_csv(topics_filepath)
        docs_df = pd.read_csv(docs_filepath)
    except FileNotFoundError as e:
        return f"오류: 파일을 찾을 수 없습니다. {e}"

    # --- 2. 토픽 단어 처리 ---
    all_topic_words = set()
    target_topic_words = set()

    for _, row in topics_df.iterrows():
        words = {word.strip() for word in row['Top_Words'].split(',')}
        all_topic_words.update(words)
        if f"T{row['Topic_Index']}" == target_topic:
            target_topic_words.update(words)

    # --- 3. 문서 데이터 처리 및 필터링 ---
    topic_cols = [f'T{i}' for i in range(0, 7)]
    docs_df['dominant_topic'] = docs_df[topic_cols].idxmax(axis=1)

    filtered_df = docs_df[
        (docs_df['wn_cls'] == target_w_cls) &
        (docs_df['dominant_topic'] == target_topic)
    ].copy() # SettingWithCopyWarning 방지를 위해 .copy() 사용

    # --- 4. 결과 문자열 생성 ---
    if filtered_df.empty:
        return f"결과 없음: 필자 분류 '{target_w_cls}'와 토픽 '{target_topic}'에 해당하는 문서가 없습니다."

    # >>>>> 변경 시작 <<<<<
    # 지정된 토픽(target_topic)의 점수를 기준으로 내림차순 정렬
    sorted_df = filtered_df.sort_values(by=target_topic, ascending=False)

    # 정렬된 결과에서 출력 개수(n) 제한 적용
    if n is not None and isinstance(n, int) and n > 0:
        display_df = sorted_df.head(n)
    else:
        display_df = sorted_df
    # >>>>> 변경 끝 <<<<<

    output_string = ""
    for _, row in display_df.iterrows():
        # 'doc_split_combined' 내용에서 토픽 단어 강조 (로직 수정)
        doc_words = row['doc_split_combined'].split(' ')
        highlighted_words = []
        for word in doc_words:
            # 1순위: 지정된 토픽의 단어는 **로 강조
            if word in target_topic_words:
                highlighted_words.append(f"**{word}**")
            # 2순위: 그 외 다른 토픽의 단어는 *로 강조
            elif word in all_topic_words:
                highlighted_words.append(f"*{word}*")
            # 3순위: 토픽 단어가 아니면 그대로 추가
            else:
                highlighted_words.append(word)
        highlighted_doc = ' '.join(highlighted_words)

        # 각 문서군의 정보를 문자열에 추가
        output_string += f"문서군_번호: {row['문서군_번호']}\n"
        output_string += f"r_no: {row['r_no']}\n"
        output_string += f"title: {row['title']}\n"
        output_string += f"w_new: {row['w_new']}\n"
        output_string += f"wn_cls: {row['wn_cls']}\n"
        output_string += f"ho_no: {row['ho_no']}\n"
        output_string += f"period: {row['period']}\n"
        output_string += f"included_doc_ids: {row['included_doc_ids']}\n"
        output_string += f"doc_count: {row['doc_count']}\n"
        output_string += f"doc_raw_combined: {row['doc_raw_combined']}\n"
        output_string += f"doc_split_combined: {highlighted_doc}\n"
        output_string += "-----\n"

    return output_string

# --- 함수 실행 예시 ---
if __name__ == "__main__":
    # 파일 경로
    DOCS_FILE = file_path + 'result/gb_data_2_doc-groups.csv'
    TOPICS_FILE = file_path + 'result/dmr_topics(토픽명 부착).csv'

    # --- 예시 1: wn_cls=1, topic=T4인 문서 전체 출력 ---
    print("--- 예시 1: wn_cls=1, topic='T4' 상위 3개 결과 ---")
    result_1 = extract_and_highlight_documents(
        docs_filepath=DOCS_FILE,
        topics_filepath=TOPICS_FILE,
        target_w_cls=1,
        target_topic='T4',
        n=3  # 출력 개수
    )
    print(result_1)
# Out:
# --- 예시 1: wn_cls=1, topic='T4' 상위 3개 결과 ---
# 문서군_번호: 190
# r_no: 53
# title: 社會問題에 先하야 自我問題에 反하라. 그리하야 社會에 對한 公僕이 되라
# w_new: 박달성
# wn_cls: 1
# ho_no: 12
# period: p1
# included_doc_ids: [928, 929, 930, 931, 932]
# doc_count: 5
# doc_raw_combined: 아 現代人아 自己를 確實히 알앗거든 人生의 如何를 深切히 覺悟하얏거든 萬人平等을 事實로 느꼇거든 覺悟한 그대로 느낀 그대로 各自 스스로가 몸소 實行하라 이써 나에 呌苦하는 問題의 세 번재이다 4 過去의 非와 今後의 是 人生의 目的이 快樂이라 하면 人生으로서는 老者 壯者 少者 男子 女子 兒童까지 누구나 다 快樂을 要求할 것이다 然한데 웨 어떤 者는 快樂의 座에서 歡喜의 웃음을 웃으며 웨 어떤者는 悲哀의 窟에서 苦痛의 눈물을 흘리고 잇는가 나는 써하되 悲哀者 스스로의 罪라 한다 人生의 目的이 功利이라 하면 또한 다 功利의 人이 되어야 되겟다 그런데 어떤 놈은 功利의 榮冠을 쓰고 어떤 놈은 退敗의 悲曲을 부르니 이것은 또한 누의 罪이겟는가 決코 功利者의 罪는 아니라 한다 人生의 目的이 自己充實이면 이도 또한 人生 全體가 다 充實하여야겟거늘 어떤 者는 充實하고 어떤 者는 不充實하니 이 또한 不充實者 스스로의 罪가 아니냐 가튼 사람으로 가튼 欲望으로 왜 快樂치 못하며 功利치 못하며 充實치 못하얏느냐 彼等의 快樂 彼等의 功利 彼等에 充實은 彼等 스스로가 努力하야 어든 것이며 또한 이 不快樂者 不功利者 不充實者로서 보내 준 것이며 도아 준 것이다 다시 말하면 彼가 快樂키 爲하야 高臺를 築하며 奴僕을 募하거늘 此로서는 勞役者가 되어 주며 奴僕으로 自進한 것이 아니냐 大將은 功利를 爲하야 만흔 犧牲을 要求하거늘 兵卒은 그 功利를 助力키 爲하야 水火自進한 것이 아니냐 彼는 知者이오 覺者이오 實力者이거늘 此는 웨 迷者며 愚者며 無力者인가 吾人은 權力家를 만히 罵倒하며 富貴者를 만히 彈劾하며 無勢力者를 만히 同情하며 貧賤者를 만히 後援하도다 吾人은 此로써 羞恥임을 不知하도다 社會에 對한 羞恥보다도 各自 自己에 對한 羞恥임을 不知하도다 니체는 일럿스되 弱者에 對한 同情처럼 罪惡이 업다 하얏나니 自己로 自己를 抛棄한 者에게 무슨 擧足의 値가 잇겟는가 그러나 此는 吾人의 經驗이 적엇든 過去의 事요 吾人의 覺醒이 不分明한 過去의 事이다 現代의 吾人은 決코 그러할 理 萬無하다 自己를 切實히 깨다른 자 어찌 如此한 不人格的 사람답지 못한 行爲가 잇슬 것이냐 今後의 人類社會는 決코 貧富貴賤 上下階級이 업슬 것을 나는 確實히 自保한다 그는 人類各自가 다 各其 自己의 權利義務를 覺하얏슴으로써 이다
# doc_split_combined: 현대_人 **自己** 확실 *인생* 深切 각오 만인 **평등** 각오 실행 *문제* *過去* 금후 *인생* 목적 쾌락 *인생* 남자 여자 아동 쾌락 요구 쾌락 환희 웃음 비애 고통 눈물 **者** 비애 *인생* 목적 功利 功利 功利 功利 **者** *인생* 목적 **自己** 충실 *인생* 전체 충실 충실 **사람** 욕망 쾌락 功利 충실 쾌락 功利 충실 노력 쾌락 노복 노역 **者** 노복 自進 功利 희생 요구 功利 知者 **者** 실력 권력 家 **者** 부귀 同情 **者** 빈천 후원 수치 不知 **사회** 수치 **自己** 수치 不知 니체 약자 同情 죄악 **自己** **自己** 포기 경험 *過去* 각성 *過去* 현대 **自己** 절실 **사람** 행위 금후 인류_사회 빈부 귀천 상하 **계급** 확실 **인류** 각자 **自己** 의무 권리
# -----
# 문서군_번호: 52
# r_no: 13
# title: 從來의 孝道를 批判하야써 今後의 父子關係를 聲言함
# w_new: 김기전
# wn_cls: 1
# ho_no: 4
# period: p1
# included_doc_ids: [252, 253, 254, 255, 256]
# doc_count: 5
# doc_raw_combined: 이제는 免하얏노라 의 一言을 殘하얏나니 그의 意는 卽 나는 이러케 나의 手足을 全히 하야 斯世를 去하나니 이제는 부모에게 불효를 免하얏다 함이다 嗚呼라 그는 父母에게 對한 不孝를 免키 爲하야 深淵에 臨하는 듯 薄冰을 履하는 듯히 戰戰又兢兢으로 그 生을 過하다가 이제는 免하얏다 는 一言으로써 最後의 安心을 作하얏다 얌전하다면 얌전하다 할는지도 不知하거니와 戰戰兢兢의 그 一生이 可憐하지 안이한가 吾人이 複雜한 이 世間에 生하야 잘되나 못되나 한 世上을 通過코저하면 特히 적어도 自己의 意志로써 살고저 하면 死生의 境을 出入하는 時도 有할지오 鉞의 間을 來往하는 事도 不無할지니 엇지 戰戰兢兢히 그 身의 毁傷을 是慮할 수가 有하리요 且夫 子된 그 身은 父母가 旣히 完全히 그에게 附與한 것이라 子된 者는 正義人道에 不悖하는 範圍內에서 그 身을 自由로 運用 又는 處分할 權利 안이 義務가 自有할지니 何特 그 身을 父母에게 全而歸하야사 孝가 될 理는 何有하리요 그 身은 말도 말고 或 父母가 自己 愛子에게 그의 所用으로 金額 幾圓 或 幾十圓을 與하얏는데 後日 그 子가 그 金을 一分도 不用하고 受領한 그대로 返納한다 하면 그 父母의 마음이 얼마나 섭섭할가 余는 이러한 意味에서 從來 孝道의 全而歸之 第一主義에 異議를 揷하노라 右의 諸項에 在하야 余는 우리 從來 孝道의 內容에 批判을 加하되 殆히 完膚가 無히 하얏다 그러나 余는 孝의 大道를 無視하는 것은 안이다 從來의 繼述 第一主義를 排한다 하야 父母의 遺業과 遺志에 無理에 反對하라 함이 안이며 從來의 爲親 第一主義를 排한다 하야 父母는 溝壑에 轉하야도 子가 그 責을 不負한다 함이 안이며 從來의 全而 歸之 第一主義를 排한다하야 父母에게서 受한 그 遺體는 함부로 毁傷하야도 可하다 함이 안이라 오 즉 非難하는 바는 世間으로 하야금 그 親이 有한 外에 又는 그 親을 事함이 有한 外에 更히 他가 有함을 認치 안이한 그것 卽 第一主義이라는 그 點이며 又는 그로부터 從生하는 弊端 그것이다 更言하면 父母의 遺志遺業을 繼하되 그 業과 志의 善惡과 又 그 業 그 志의 子된 그 사람의 趣味技能에 適否 如何를 擇하라 함이며 그 親을 爲하되 子된 自身과 又는 自己의 子女가 更有함을 認하라 함이오 그 身을 全히 하되 그저 父母의 遺體이라 하야 戰兢主義에 拘囚되지는 말라 함이다 一言으로 蔽하면 사람은 그 自身이 親의 分身임을 知하는 以外에 更히 그 身은 사람의 한아임을 知하야 子의 身分으로써 살이하는 同時에 사람의 身分으로써 살라 함이다 우리는 今日까지 그저 孝道 孝道하야 그의 神聖함만 認하고 그의 暗面을 不察하얏슴으로써 恬然 自過함을 得하나 孝에 對한 批判의 眼으로써 그의 産한 暗面 卽 末弊를 思하면 一刻이나마 그대로 看過할 수가 업슬 것이다 從來 孝道의 爲親 第一主義는 不知中 親權萬能을 釀出하야 父母는 그 子女를 自己의 一種 所有物로 認하고 子女의 身上에 關한 一切를 그가 獨斷하게 되매 子女 一生의 大問題인 結婚과 如함도 兩家 父母가 恣行하야 妻를 取케함은 그 子의 살림을 爲함이 안이오 一家라는 그것의 勞役 又는 自己의 悅樂을 滿足키 爲함이라 故로 一般의 結婚期는 無理히 早하게 되어 三十而有室은 單十而有室이 되며 제 子息의 取妻期는 이러케 早함에 反하야 며느리 되는 女子는 十六七歲의 適齡을 取하야 同居를 强制하며 甚한 者는 自己의 生計를 爲하야 그 女를 放賣하며 現在 所謂 兩班階級에 在하야도 그 女로써 或 權門에 阿附하는 段階를 삼는 者가 有하며 그리고 依例 父母의 責任되는 子女敎育에 至하야는 敎育 與否도 自己의 任意이라 하야 膝下의 昵情 又는 其他 自己의 便宜를 計하기 爲하야 相當 敎育을 不施 又는 不肯하며 尙 子女는 自己의 所有라 하야 愛憎을 恣行하야 그 子의 惡과 他人의 善을 不知하며 甚한 者는 自己의 子女는 아모러케 取扱하야도 그만이라 하야 叱辱毆打의 私刑을 濫行하는 等 一一히 例를 擧하자면 限이 無하다 父母의 濫權은 如斯하되 子女는 그에 對하야 敢히 一言의 異議를 唱치 못하며 或 反旗를 擧하면 世間은 곳 그에게 不孝의 罪名을 加하야 社會에 立함을 不許한다 뿐만 안이라 誰이나 此에 感하야 口이나 或 筆로써 從來 道德의 內容 又는 그의 末弊를 非難하면 곳 倫綱 을 不知하는 者이니 或은 無祖無父의 惡한이니 하야 一部의 固陋無事輩는 함부로 덤비나니 이리하고 엇지 社會的 改革을 期할 수 有하리요 今後의 父子關係 天倫으로부터 出하는 人子의 그 親에게 대한 至情은 寧히 此를 助長할지언정 可히 沮止치 못할 것이며 그러타 하야 從來 孝道의 認한 그것은 可히 襲用치 못할것이라 오즉 時代思想의 見地 밋헤서 新孝道主義를 우리가 提唱하야 今後의 父子關係를 一新케 할 外에 無할지니 兄弟여 余로 하야금 此에 對한 管見을 要領뿐 陳述케 함이 有하라 一 子의 親에게 對한 孝의 程度는 天然으로 流出하는 그 感情의 攸命에 限하고 更히 他 意義를 牽强附會함이 無케 하라 一 父子間에 在하야는 子가 그 父를 爲하고 그 父가 또 그 父를 爲하는 從來 道德의 回顧主義를 去하고 그 父가 그 子를 爲하고 그 子가 또 그 子를 爲하는 現今 道德의 理想主義를 취하라 一 親된 者는 그 子女가 自己의 掌中物이 안이오 完全한 人임을 認하며 子된 者도 亦 自身은 他人의 子가 되는 外에 獨立한 人이 된 것을 記할 것이라 一 親되는 者는 一子女를 生함과 共히 그 子女를 充分히 기르고 가르칠 毅武를 必負하되 그 義務를 履行치 못할 境遇이면 寧히 子女의 産出을 回避할 道를 講할 것이며 또 親되는 者는 自身이 老衰하기 前에 小하야도 自身을 養할 資産을 有하야 그 子에게 扶養을 要求치 안토록 할 것이니 그러치 못하면 그 子가 또 그 子에게 對한 責을 盡치 못하게 됨으로써라
# doc_split_combined: 수족 부모 부모 최후 안심 不知 일생 가련 복잡 세간 세상 통과 **自己** 意志 死生 출입 부모 완전 附與 人道_正義 범위 **자유** 운용 처분 권리 의무 **자유** 부모 부모 **自己** 소용 금액 후일 分子 부모 마음 *의미* 종래 효도 **主義** 第一 이의 종래 효도 내용 비판 大道 무시 종래 第一 **主義** 부모 無理 반대 종래 **主義** 第一 부모 종래 **主義** 第一 부모 비난 세간 第一 **主義** 폐단 부모 선악 **사람** 취미 기능 自身 **自己** 자녀 부모 **사람** 自身 **사람** 아이 신분 **사람** 신분 **금일** 효도 효도 神聖 恬然 비판 간과 종래 효도 **主義** 第一 不知 부모 자녀 **自己** 소유 物 자녀 일체 독단 자녀 일생 大 *문제* 결혼 부모 恣行 살림 一家 노역 **自己** 만족 일반 결혼 期 無理 자식 여자 강제 **自己** 생계 방매 *현재* **계급** 양반 권문 依例 부모 책임 *교육* 자녀 *교육* **自己** 임의 **自己** 편의 *교육* 자녀 **自己** 소유 恣行 타인 不知 **自己** 자녀 취급 부모 자녀 이의 세간 **사회** 불허 종래 **도덕** 내용 비난 不知 一部 **사회** 개혁 금후 父子 **관계** 조장 저지 종래 효도 *시대* *사상* 견지 *新* **主義** 효도 提倡 금후 **관계** 父子 一新 *형제* 진술 천연 *감정* 의의 間 父子 종래 **도덕** **主義** 회고 현금 **도덕** 理想_主義 자녀 **自己** 物 掌中 완전 自身 타인 독립 자녀 자녀 충분 의무 이행 자녀 산출 회피 自身 노쇠 自身 자산 부양 요구
# -----
# 문서군_번호: 261
# r_no: 71
# title: 生活의 條件을 本位로 한 朝鮮의 改造事業, 이 글을 特히 民族의 盛衰를 雙肩에 負한 靑年諸君에 부팀
# w_new: 이돈화
# wn_cls: 1
# ho_no: 15
# period: p1
# included_doc_ids: [1287, 1288, 1289, 1290, 1291, 1292]
# doc_count: 6
# doc_raw_combined: 萬一 生活이 急變함에 不拘하고 道德은 如前히 千古不變이라 하면 그는 經濟의 現像이 變함에 不拘하고 物價는 如前히 支續된다 함과 如함이라 그럼으로 生活과 道德은 形影의 相隨와 가트여 須臾라도 可히 離치 못할 것이라 하겟다 우리 朝鮮의 道德이라 하는 것은 本來 儒敎의 道德이 그의 根本 基礎엇나니 儒敎의 道德은 누구나 다 아는 바와 가티 恒常 過去를 標準한 道德이라 先王의 法이 아니면 行치 아니하며 先王의 言과 行이 아니면 用치 못하리라 斷定한 道德이라 그럼으로 그 性質이 極히 消極的이며 極히 退屈的이엇나니 屢百年來 이러한 消極的 退屈的 道德뿐 지켜온 朝鮮民族은 어느덧 창조의 力을 일코 말앗스며 活動의 氣를 막고 말앗다 그럼으로 우리가 이제로부터 合時代的 生活條件을 짓고저 함에는 무엇보다도 먼저 이 道德의 觀念을 改造하야 消極으로부터 積極에 나아가는 길을 열지 아니함이 不可하며 退屈로부터 進步에 나아가는 元氣를 養치 아니함이 不可하겟다 다시 말하면 少年半島의 今日의 道德은 活動主義의 道德이 아니면 今日의 生活條件과 竝行치 못하리라 이르리라 이제 吾人의 思考한 바의 또는 가장 取할만한 바의 道德的 觀念은 알에와 가튼 條件下에 實施되어야 할 것이라 呌呼함을 마지 아니 한다 은 自主的 道德이니 自主的 道德이라 하는 것은 道德의 觀念을 絶對로 人格主義의 上에 두지 아니하면 不可타 함이라 過去와 가티 道德을 한 命令的 機械的으로 遂行하야 他의 命令을 從하며 他의 支配뿐 隨하야 行케 되지 아니하고 반듯이 自己라 하는 個體의 人格을 主로 하야 그 主體로부터 울어 나오는 道德이라야 可히써 今日의 道德이라 할 것이다 그럼으로 人格主義의 道德은 自己로 能히 道德을 理解하며 道德을 批判하며 道德을 自主하야 自己의 事를 能히 自己로 判斷하는 道德이 되지 아니함이 不可하겟다 例하면 生徒가 學校規則을 服從함은 是 道德됨에 異議가 업스나 그러나 學校의 規則이라 하야 生徒가 그를 盲目으로 機械的으로 服從하니 보다 一層 그 規則을 生徒自體의 正當行爲로 自認하야 비록 學校의 規則이 업다 할지라도 生徒된 者는 반듯이 그러한 規律을 지키지 아니하면 안되리라 하는 自主의 道德觀念을 養케 하는 것이 可하며 國民이 國法에 服從함은 是 道德됨에 異議가 업스나 그러나 國法이라 하야 國民이 그를 盲目的 機械的으로 服從하니 보다 一層 進하야 國民自體가 自覺의 力으로써 비록 國法이 업다 할지라도 能히 그만한 人民의 集團에는 그러한 行動이 必要하리라는 自主의 觀念으로써 法律에 先하야 道德的으로 國民全體의 幸福을 造成케 함이 이곳 自主의 道德이라 할 것이다 이를 政治의 發達로써 比較하건대 過去 君主專制의 時代에는 國民이 自己의 國事를 自己들의 力으로 能히 處判치 못하고 一個人 專制君主의 力에 依하야 機械的 盲目的으로 그 國法을 服從케 되엇스나 今日의 立憲時代에 至하야는 國民이 自己의 知와 力으로써 自國의 事를 人民 自體가 處理케 되엇나니 道德도 또한 이와 가트여 過去의 道德은 人民의 自主力이 업시 古人의 遺訓 或은 祖先의 遺法을 盲從함에 지내지 아니 하엿스나 今日은 政治上에 立憲을 實行함과 가티 道德에도 또한 立憲을 주로 하지 아니치 못할지니 即 自主主義의 道德에서는 自己 스스로가 立法者가 되며 司法者가 되며 行政者가 되어 自己의 事를 自己로 能히 處辨할만한 道德의 主體가 되어야 할 것이다 는 合時代的 道德이니 合時代的 道德이라 함은 以上에 述함과 가티 道德은 恒常 生活條件과 竝行하는 故로 太古의 生活에는 太古의 道德이 必要함과 가티 今日의 生活에는 또한 今日의 道德이 必要하나니 試思하라 우리의 生活이 이미 祖先의 生活과는 千萬里의 距離가 生하엿슴에 不拘하고 此에 竝行하는 道德뿐이오 即 祖先時代의 道德이 必要하다 하면 그는 全혀 時代에 盲目한 者라 이르지 안켓나뇨 그럼으로 合時代的 道德이라 하는 것은 決코 習慣에 盲從하며 祖先時代의 行하던 일이라 하야 이를 頑守하야서는 아니 될 것이다 例하면 祖先時代에는 國家道德上 國民과 君主의 間에 用하던 道德觀念은 今日에 至하야는 全部 或은 一部의 絶對 變遷이 有함과 가튼 것이며 又 家庭道德上에서 過去에는 祖先中心이엇던 道德이 今日에 至하야 子孫中心主義로 變하엿스며 夫婦道德에서 婦는 絶對로 夫에 死守貞操이엇던 道德이 今日에 至하야는 婦人解放主義에 因하야 婦人의 權利를 男子와 平等으로 引上코저 하는 것이며 社會道德上에서 過去에는 노동자가 絶對로 資本主에게 盲從하던 習慣이 今日에 至하야는 노동本位로 因하야 勞資의 調和를 叫呼하는 것과 如한 등은 다 가티 昔日의 道德과 今日의 道德의 間에 正反對의 變遷을 生케 한 것이라 如斯히 道德의 觀念이 生活의 條件과 逐年 竝行함에 不拘하고 一部 頑固者流가티 道德은 이 千古不變이라 하야 先王의 法이 아니면 行치 아니하며 先王의 言과 行이 아니면 從치 아니하다함은 實로 滅亡性을 預期한 人種이라 云치 아니치 못할지라 吾人은 모름직이 時代的 生活과 竝行하는 道德을 창조하며 時代와 順應하는 道德을 養치 아니함이 不可하나니 다시 말하면 道德의 改造를 時代에 竝行케 하여야 할 것이엇다 은 共同의 道德이니 共同의 道德이라 하는 것은 道德을 一個 個人의 生活條件으로 보지 말고 少하야도 國民 全體의 生活條件 或은 世界 全人類의 生活條件으로 看做하야 道德의 範圍를 世界共通的 條件으로 하면 道德의 活用을 世界同化的 眞理로 應用케 하는 것이엇다 例하면 今日 世界를 通한 人道正義의 聲과 如함은 이 決코 一個人 或은 一國家에 關한 道德이 아니오 國際的으로 道德의 美를 生活條件의 上에 表顯코저 함이니 今日의 道德은 部落時代 或은 鎖國時代의 單偏的 生活條件뿐 並行하던 道德이 아니라 비록 一個人의 行爲라 할지라도 그가 문득 世界的 或은 國際的 生活條件과 伴行하는 實例가 多하나니 그럼으로 余 一個人의 身은 다만 余 一家庭의 身 或 余 一國家의 身이라 하니보다 차라리 全世界의 身이 되나니 이 點에서 余 一個人의 道德上 行爲는 다만 余의 一家族 又는 一國家에 뿐 止함이 아니오 어떤 意味에서 全世界의 道德上 行爲가 된다 이를 것이라 共同의 道德이라 하는 것을 簡單히 一言으로 要言하면 調和의 道德이라 하는 意味이니 例言하면 前述한 男女의 道德이라 할지라도 己往에는 男尊女卑로 잇던 것을 그를 調和하야 男女平等主義의 道德을 써야함과 가티 노동자와 資本主의 間에 道德도 그러하여야 하고 强者와 弱子間의 道德도 그러하여야 하고 優者와 劣者間의 道德도 그러하여야 할 것이엇다 이 곳 共同의 道德이니 이러한 道德이 아니면 現代의 生活條件과 並行치 못할 것이라 如斯히 今日의 道德은 積極的 向上的인 活動主義의 上에 두지 아니함이 不可하며 그리하야 그 條件을 徹頭徹尾 生活條件의 上에 두지 아니함이 不可하겟다
# doc_split_combined: **생활** **도덕** 千古 불변 *경제* 현상 물가 지속 **생활** **도덕** *朝鮮* **도덕** 본래 *유교* **도덕** 근본 기초 *유교* **도덕** 항상 *過去* 표준 **도덕** 선왕 선왕 단정 **도덕** 성질 소극 퇴굴 소극 퇴굴 **도덕** 朝鮮_민족 *창조* 활동 조건 **생활** **도덕** **관념** *개조* 소극 적극 不可 퇴굴 진보 원기 *소년* 반도 **금일** **도덕** **主義** 활동 **도덕** **금일** 생활_조건 병행 사고 **도덕** **관념** 조건 실시 규호 자주 **도덕** 자주 **도덕** **도덕** **관념** *절대* **主義** **인격** 不可 *過去* **도덕** 명령 機械 수행 명령 지배 **自己** 개체 **인격** 주체 **도덕** **금일** **도덕** **主義** **인격** **도덕** **自己** **도덕** 理解 **도덕** 비판 **도덕** 자주 **自己** **自己** 판단 **도덕** 生徒 규칙 *학교* 복종 **도덕** 이의 *학교* 규칙 生徒 맹목 機械 복종 규칙 자체 生徒 행위 正當 自認 *학교* 규칙 生徒 규율 자주 **도덕** **관념** *국민* 국법 복종 **도덕** 이의 국법 *국민* 맹목 機械 복종 자체 *국민* 자각 국법 인민 집단 행동 *필요* 자주 **관념** 법률 **도덕** 전체 *국민* **행복** 造成 자주 **도덕** *정치* *발달* 비교 *過去* 군주 專制 *시대* *국민* **自己** 國事 **自己** **개인** 군주 專制 機械 맹목 국법 복종 **금일** 입헌 *시대* *국민* **自己** 자국 인민 자체 처리 **도덕** *過去* **도덕** 인민 力 자주 古人 祖先 맹종 **금일** *정치* 입헌 실행 **도덕** 입헌 자주 **主義** **도덕** **自己** **者** 사법 **者** 行政 **自己** **自己** **도덕** 주체 **도덕** **도덕** **도덕** 항상 조건 **생활** 병행 태고 **생활** 태고 **도덕** *필요* **금일** **생활** **금일** **도덕** *필요* **생활** 祖先 **생활** 距離 병행 **도덕** 祖先 *시대* **도덕** *필요* *시대* 맹목 **도덕** 습관 맹종 *시대* 祖先 *시대* 祖先 **도덕** **국가** *국민* 군주 **관념** **도덕** **금일** 전부 一部 *절대* 변천 가정 **도덕** *過去* 祖先 중심 **도덕** **금일** 중심 **主義** 자손 **도덕** 부부 *절대* **도덕** **금일** **主義** 해방 婦人 婦人 권리 남자 **평등** 引上 **사회** **도덕** *過去* *노동_者* *절대* 主 *자본* 맹종 습관 **금일** *노동* 본위 勞資 調和 규호 昔日 **도덕** **금일** **도덕** 正_반대 변천 **도덕** **관념** 생활_조건 병행 一部 **者** 완고 流 **도덕** 불변 千古 선왕 선왕 性 멸망 예기 人種 *시대* **생활** 병행 **도덕** *창조* *시대* 순응 **도덕** 不可 **도덕** *개조* *시대* 병행 공동 **도덕** 공동 **도덕** **도덕** 일개 **개인** 생활_조건 *국민* 전체 생활_조건 *세계* 全 인류_생활 생활_조건 간주 **도덕** 범위 공통 *세계* 조건 **도덕** 활용 *세계* 同化 진리 응용 **금일** *세계* 人道_正義 **개인** **국가** **도덕** *국제* **도덕** 美 생활_조건 표현 **금일** **도덕** *시대* 부락 *시대* 쇄국 생활_조건 병행 **도덕** **개인** 행위 *세계* *국제* 조건 **생활** 伴行 實例 **개인** 가정 **국가** 全 *세계* **개인** **도덕** 행위 가족 **국가** *의미* 全 *세계* **도덕** 행위 공동 **도덕** 간단 調和 **도덕** *의미* 남녀 **도덕** 調和 남녀 **평등** **主義** **도덕** *노동_者* *자본* 主 **도덕** 강자 間 약자 **도덕** 優者 間 劣者 **도덕** 공동 **도덕** **도덕** 현대 생활_조건 병행 **금일** **도덕** 적극 향상 **主義** 활동 조건 철미 철두 조건 **생활**
# -----

# %% [markdown]
# ## 3.4.엠에디터로 확인: 마커 기능
# - 엠에디터로 이동

# %% [markdown]
# # The End of Note
